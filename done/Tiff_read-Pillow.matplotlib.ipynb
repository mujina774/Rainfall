# %% [markdown]
# ## matplotlibで TIFF読むと unit8/RGBA

# %%
import numpy as np
import matplotlib.pyplot as plt

f = './im/2023/GPM_3IMERGM_2023-01-01_gs_3600x1800.FLOAT.tiff'
mp = plt.imread(f)
print(mp.shape)
mp.dtype
plt.imshow(mp, cmap="gray")
# Out:
# (1800, 3600, 4)

# %% [markdown]
# ## matplotlibで png 読むと float32/G

# %%
import numpy as np
import matplotlib.pyplot as plt

f = './im/2023/png/RenderData (1).png'
mp = plt.imread(f)
print(mp.shape)
print(mp.dtype)
print(np.max(mp), '\t', np.min(mp))
plt.imshow(mp, cmap="gray")
# Out:
# (1800, 3600)
# float32
# 1.0 	 0.0

# %% [markdown]
# ## pillowで TIFF 読むと float32/G

# %%
from PIL import Image

f = './im/2023/GPM_3IMERGM_2023-01-01_gs_3600x1800.FLOAT.tiff'
ml = np.array(Image.open(f))
print(ml.shape)
ml.dtype
plt.imshow(ml, cmap="gray")
# Out:
# (1800, 3600)

# %% [markdown]
# ## pillowで png 読むと unit8/G

# %%
from PIL import Image

f = './im/2023/png/RenderData (1).png'
ml = np.array(Image.open(f))
print(ml.shape)
ml.dtype
plt.imshow(ml, cmap="gray")
# Out:
# (1800, 3600)

# %% [markdown]
# ## Loopで回しても同じ

# %%
import glob

p = 'im/2023/'
f = glob.glob(p + '*.tiff')
for i in f:
    mp = plt.imread(i)
    print(mp.dtype)
# Out:
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8

# %%
import glob

p = 'im/2023/'
f = glob.glob(p + '*.TIFF')
for i in f:
    mp = np.array(Image.open(i))
    print(mp.dtype)
# Out:
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32
# float32

# %% [markdown]
# ## ラスターTIFFは読め無い

# %%
f = './im/2023/RenderDatar.tiff'
ml = np.array(Image.open(f))
print(ml.shape)
ml.dtype
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[30], line 2
#       1 f = './im/2023/RenderDatar.tiff'
# ----> 2 ml = np.array(Image.open(f))
#       3 print(ml.shape)
#       4 ml.dtype
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\PIL\Image.py:3309, in open(fp, mode, formats)
#    3307     warnings.warn(message)
#    3308 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3309 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file './im/2023/RenderDatar.tiff'

# %%
f = './im/2023/RenderDatar.tiff'
mp = plt.imread(f)
print(mp.shape)
mp.dtype
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[28], line 2
#       1 f = './im/2023/RenderDatar.tiff'
# ----> 2 mp = plt.imread(f)
#       3 print(mp.shape)
#       4 mp.dtype
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:2404, in imread(fname, format)
#    2400 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2401 def imread(
#    2402         fname: str | pathlib.Path | BinaryIO, format: str | None = None
#    2403 ) -> np.ndarray:
# -> 2404     return matplotlib.image.imread(fname, format)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\image.py:1525, in imread(fname, format)
#    1518 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1519     # Pillow doesn't handle URLs directly.
#    1520     raise ValueError(
#    1521         "Please open the URL for reading and pass the "
#    1522         "result to Pillow, e.g. with "
#    1523         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1524         )
# -> 1525 with img_open(fname) as image:
#    1526     return (_pil_png_to_float_array(image)
#    1527             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1528             pil_to_array(image))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\PIL\Image.py:3309, in open(fp, mode, formats)
#    3307     warnings.warn(message)
#    3308 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3309 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file './im/2023/RenderDatar.tiff'
